# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests


# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0  port-aux-francais -49.3500   70.2167      1.40        90
# 1        1          greymouth -42.4667  171.2000      9.07        82
# 2        2  bikenibeu village   1.3673  173.1241     26.98        83
# 3        3      port mathurin -19.6833   63.4167     23.16        80
# 4        4          grytviken -54.2811  -36.5092      2.45        92
#
#    Cloudiness  Wind Speed Country        Date
# 0          99        6.73      TF  1696089998
# 1         100        5.63      NZ  1696090161
# 2          75        1.54      KI  1696090018
# 3          76       10.73      MU  1696090013
# 4          27        4.24      GS  1696090005

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    size = "Humidity",
    color = "City"
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
df = city_data_df[(city_data_df["Max Temp"] > 24) & (city_data_df["Humidity"] > 40) & (city_data_df["Cloudiness"] < 31)]

# Drop any rows with null values
df = df.dropna(how="any")

# Display sample data
df.head()
# Out:
#     City_ID      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 23       23  west bay  19.3667  -81.4167     32.81        76          18
# 56       56    uturoa -16.7333 -151.4333     25.88        79          19
# 63       63  hamilton  39.1834  -84.5333     25.89        72           0
# 74       74    hirara  24.8000  125.2833     28.19        83           5
# 76       76     rapar  23.5667   70.6333     31.35        47          10
#
#     Wind Speed Country        Date
# 23        0.45      KY  1696090175
# 56        8.80      PF  1696090073
# 63        2.57      US  1696089930
# 74        6.93      JP  1696090188
# 76        0.94      IN  1696090189

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df.head()
# Out:
#         City Country      Lat       Lng  Humidity Hotel Name
# 23  west bay      KY  19.3667  -81.4167        76
# 56    uturoa      PF -16.7333 -151.4333        79
# 63  hamilton      US  39.1834  -84.5333        72
# 74    hirara      JP  24.8000  125.2833        83
# 76     rapar      IN  23.5667   70.6333        47

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
        "categories" : "accommodation.hotel",
        "apiKey": geoapify_key,
        "limit": 20,
    }

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    Lat = row["Lat"]
    Lng = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{Lng},{Lat},{radius}"
    params["bias"] = f"proximity:{Lng},{Lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"
    
    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
    
# Display sample data
hotel_df
# Out:
# Starting hotel search
# west bay - nearest hotel: Bonnie's Arch
# uturoa - nearest hotel: Hawaiki Nui hotel
# hamilton - nearest hotel: North Vista Manor
# hirara - nearest hotel: 古謝そば屋
# rapar - nearest hotel: No hotel found
# georgetown - nearest hotel: Page 63 hostel
# touros - nearest hotel: Pousada Atlântico
# taulaga - nearest hotel: No hotel found
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# saint-denis - nearest hotel: Tribe
# savanna-la-mar - nearest hotel: Kibo Hotel
# san patricio - nearest hotel: No hotel found
# shantou - nearest hotel: 金海湾大酒店
# yung shue wan - nearest hotel: 浪濤軒酒店 Concerto Inn
# ta`u - nearest hotel: No hotel found
# pine bluff - nearest hotel: Days Inn & Suites by Wyndham Pine Bluff
# sur - nearest hotel: Sur Hotel
# kourou - nearest hotel: SCI Horizon
# red hill - nearest hotel: No hotel found
# mahdia - nearest hotel: La Maison Bleue
# machico - nearest hotel: Residence Inn
# bodden town - nearest hotel: Turtle Nest Inn
# cabo san lucas - nearest hotel: Comfort Rooms
# soure - nearest hotel: Hotel Marajó
# xai-xai - nearest hotel: No hotel found
# tazacorte - nearest hotel: App Leyma
# al majaridah - nearest hotel: No hotel found
# kingston - nearest hotel: Aphrodite Hotel
# bandarbeyla - nearest hotel: No hotel found
# cefa - nearest hotel: No hotel found
# inhambane - nearest hotel: Hotel de Inhambane
# porto novo - nearest hotel: Hôtel 6500 CFA
# guiping - nearest hotel: 西山假日大酒店
# saipan - nearest hotel: Chalan Kanoa Beach Hotel
# ji'an - nearest hotel: 华侨国际酒店
# sabang - nearest hotel: Sabang Hill
# kailua-kona - nearest hotel: Kona Seaside Hotel
# nandu - nearest hotel: No hotel found
# cascais - nearest hotel: Cascais Hotel
# imgarr - nearest hotel: Golden Sands
# itaituba - nearest hotel: TG Hotel
# kani keli - nearest hotel: Hôtel Le Jardin Maoré
# kismayo - nearest hotel: Kismayo Hotel
# sattahip - nearest hotel: blue warehouse home
# chake chake - nearest hotel: Annex Pemba Hotel
# mogadishu - nearest hotel: Villa Rays Restaurant & Hotel
# anzio - nearest hotel: B&B Il Paradiso sul Mare
# beatrice - nearest hotel: No hotel found
# lihue - nearest hotel: Kauai Palms
# didim - nearest hotel: Temple Grup otel
# maintirano - nearest hotel: Hotel Safari
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# la passe - nearest hotel: L'Estuaire
# cangas de onis - nearest hotel: No hotel found
# kigoma - nearest hotel: sunset vista hotel
# hobyo - nearest hotel: No hotel found
# lata - nearest hotel: Residencial Botânico
# dwarka - nearest hotel: The Dwarika Hotel
# nedroma - nearest hotel: No hotel found
# north madison - nearest hotel: Clifty Inn
# rio hato - nearest hotel: Playa Blanca Hotel & Resort
# acarau - nearest hotel: No hotel found
# stephenville - nearest hotel: No hotel found
# nishinoomote - nearest hotel: ゼウスハウス
# ad darb - nearest hotel: No hotel found
#              City Country      Lat       Lng  Humidity  \
# 23       west bay      KY  19.3667  -81.4167        76
# 56         uturoa      PF -16.7333 -151.4333        79
# 63       hamilton      US  39.1834  -84.5333        72
# 74         hirara      JP  24.8000  125.2833        83
# 76          rapar      IN  23.5667   70.6333        47
# ..            ...     ...      ...       ...       ...
# 513      rio hato      PA   8.3833  -80.1667        71
# 542        acarau      BR  -2.8856  -40.1200        51
# 545  stephenville      US  32.2207  -98.2023        55
# 566  nishinoomote      JP  30.7333  131.0000        73
# 568       ad darb      SA  17.7229   42.2526        61
#
#                       Hotel Name
# 23                 Bonnie's Arch
# 56             Hawaiki Nui hotel
# 63             North Vista Manor
# 74                         古謝そば屋
# 76                No hotel found
# ..                           ...
# 513  Playa Blanca Hotel & Resort
# 542               No hotel found
# 545               No hotel found
# 566                       ゼウスハウス
# 568               No hotel found
#
# [65 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    color="City",
    line_color="black",
    size=80,
    frame_width=700,
    frame_height=500,
    hover_cols=["Hotel Name", "Country", "Humidity"],
    title=f'Humidity and Nearest Hotel within 10km on {9/30/2023}',
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name,Country,Humidity)
